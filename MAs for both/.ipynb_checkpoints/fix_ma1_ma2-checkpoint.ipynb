# %%
import pandas as pd

# %%
concepts = pd.read_csv('AD_refConcepts.csv', sep=';')
ma1 = pd.read_csv('MA1_Data.csv', sep=';')
ma2 = pd.read_csv('MA2_Data.csv', sep=';')

# %%
df_inner_ma1 = pd.merge(concepts, ma1, on='pmid', how='inner')
df_inner_ma1 = df_inner_ma1[~df_inner_ma1.cuis.str.startswith(('[]'))]

# %%
df_inner_ma2 = pd.merge(concepts, ma2, on='pmid', how='inner')
df_inner_ma2 = df_inner_ma2[~df_inner_ma2.cuis.str.startswith(('[]'))]

# %%
df_inner_ma1
# Out:
#         pmid                                               cuis  \
# 7    2360411  ["C0231448:1", "C3816499:1", "C1524031:1", "C0...
# 10   7790979  ["C2825406:1", "C0184666:1", "C1709709:1", "C0...
# 15  14720173  ["C0459385:1", "C1883709:1", "C0234402:1", "C1...
# 17  15910550  ["C0085262:4", "C1628982:1", "C0026237:1", "C0...
# 20  21709248  ["C0518083:1", "C0449243:2", "C0585034:1", "C1...
# 22  23532874  ["C1628982:1", "C1880198:1", "C3266814:6", "C0...
# 23  23850330  ["C2986411:1", "C2700280:1", "C0424093:4", "C0...
# 24  24217277  ["C1512899:1", "C1514228:1", "C0039082:1", "C1...
# 25  24967550  ["C0037747:1", "C0542341:1", "C0183115:1", "C0...
# 26  25533477  ["C0205454:1", "C0004448:3", "C0039082:1", "C0...
# 28  26718979  ["C0206181:4", "C1550501:8", "C0016263:2", "C0...
# 29  27143430  ["C0200767:1", "C1552738:1", "C0686907:1", "C2...
# 30  27213057  ["C3687794:1", "C0205171:1", "C3484390:1", "C0...
# 31  22614246  ["C0004448:3", "C0039082:1", "C0085631:1", "C0...
# 32  25164377  ["C1880355:1", "C1306372:5", "C0459385:2", "C1...
# 33  28143566  ["C1280997:1", "C0001554:1", "C0933845:1", "C0...
# 36  12670422  ["C2825407:1", "C0030761:2", "C0206181:1", "C0...
# 41  27671875  ["C1705285:1", "C1832428:1", "C0205396:1", "C2...
# 42  23831058  ["C1096775:1", "C1880355:1", "C0002726:1", "C3...
# 43  24117480  ["C2986411:1", "C2825407:1", "C1550502:2", "C1...
# 44  28547865  ["C2004062:1", "C0001280:1", "C0699748:2", "C0...
# 45  25531153  ["C0425382:1", "C0439836:1", "C2926606:2", "C0...
# 46  25752209  ["C0085262:2", "C0424093:1", "C1550501:9", "C0...
# 47  27127658  ["C1706276:1", "C3534339:1", "C0699748:2", "C2...
# 48  23314940  ["C2700280:1", "C1512899:1", "C0200760:1", "C0...
# 49  28004889  ["C1513392:1", "C0017243:1", "C0600688:1", "C0...
# 50  27984697  ["C1880355:1", "C0001554:2", "C0699748:6", "C1...
# 52  25934229  ["C1513392:1", "C0017243:1", "C0600688:1", "C0...
# 53  23326437  ["C1328819:1", "C0178784:1", "C0439834:1", "C1...
# 55  20383142  ["C0030761:1", "C0206181:1", "C2986417:1", "C0...
# 58  19689163  ["C2986411:2", "C1168005:1", "C0870951:1", "C0...
# 59  20454932  ["C0001554:1", "C0699748:2", "C1527148:1", "C2...
# 60  16914866  ["C3534339:1", "C0205088:1", "C1879646:1", "C1...
# 61  20523048  ["C3844666:1", "C0332181:1", "C0332183:1", "C1...
# 62  19955704  ["C0001554:1", "C0596260:1", "C0699748:3", "C0...
# 63  21636582  ["C0344315:1", "C0229992:3", "C0600653:1", "C0...
# 64  19747159  ["C3266814:2", "C0001554:5", "C0009968:1", "C0...
# 67  21047545  ["C0459385:1", "C0699748:1", "C0933845:1", "C2...
# 69  19500576  ["C0038454:1", "C1883712:1", "C0001554:1", "C0...
# 73  16371011  ["C0035696:2", "C0241888:2", "C0459385:3", "C0...
# 75  18258207  ["C0220806:2", "C0459385:1", "C0699748:2", "C0...
# 77  12106813  ["C0596260:1", "C1710263:1", "C0205088:2", "C0...
# 79  12020857  ["C0002395:1", "C0237881:1", "C0205246:1", "C0...
# 81  10936685  ["C1444754:4", "C1522579:1", "C0678594:1", "C0...
# 87  10332536  ["C0079809:1", "C0683212:1", "C0002395:2", "C1...
#
#        Manual Class Unnamed: 2
# 7                AD        NaN
# 10               AD          *
# 15               AD          *
# 17              FAD        NaN
# 20              FAD          *
# 22               AD          *
# 23  FAD, EOAD, LOAD        NaN
# 24               AD          *
# 25               AD          *
# 26               AD          *
# 28               AD          *
# 29             LOAD          *
# 30               AD          *
# 31               AD          *
# 32        FAD, EOAD          *
# 33              FAD          *
# 36              FAD          *
# 41               AD          *
# 42               AD          *
# 43               AD          *
# 44               AD          *
# 45               AD          *
# 46               AD          *
# 47               AD          *
# 48               AD        NaN
# 49               AD          *
# 50               AD          *
# 52               AD          *
# 53               AD          *
# 55               AD          *
# 58               AD          *
# 59               AD          *
# 60               AD          *
# 61               AD        NaN
# 62               AD        NaN
# 63               AD          *
# 64               AD          *
# 67               AD        NaN
# 69               AD          *
# 73               AD        NaN
# 75               AD        NaN
# 77               AD          *
# 79               AD          *
# 81               AD          *
# 87               AD        NaN

# %%
df_inner_ma2
# Out:
#         pmid                                               cuis  \
# 0   29050382  ["C1550501:1", "C0009667:2", "C0699748:1", "C0...
# 1   27103528  ["C1880355:1", "C1550501:1", "C1709599:1", "C0...
# 3   23613741  ["C0079809:1", "C2986827:1", "C0032743:1", "C0...
# 4   23415546  ["C1552738:1", "C0439831:1", "C0699748:1", "C3...
# 5   22459297  ["C3266812:1", "C0030761:1", "C0150098:3", "C0...
# 6   22015308  ["C1880355:1", "C0030761:1", "C0241888:6", "C0...
# 7   21316814  ["C0542339:1", "C0443147:1", "C0542341:1", "C0...
# 8   20375137  ["C2825407:1", "C0013109:1", "C0019425:1", "C0...
# 9   19604328  ["C0030761:1", "C1533691:1", "C0443147:1", "C0...
# 12  15364419  ["C0030761:5", "C1628982:1", "C1550501:1", "C0...
# 13  15179443  ["C0023688:2", "C0036658:1", "C1550501:1", "C0...
# 14  14552909  ["C0030761:2", "C1533691:1", "C0205088:1", "C0...
# 15  11848684  ["C2246292:1", "C0596260:1", "C0699748:2", "C0...
# 89  27889917  ["C0857690:1", "C0459385:1", "C2986417:1", "C0...
# 91  19506424  ["C1512612:1", "C0015272:1", "C0004083:2", "C0...
# 92  17198748  ["C0041485:2", "C0682523:1", "C1260953:1", "C0...
# 93  14753054  ["C2986411:1", "C1273869:1", "C1279889:2", "C0...
# 94  11882748  ["C1422662:1", "C1705242:2", "C0439834:2", "C0...
#
#        Manual Class Unnamed: 2
# 0        EOAD, LOAD          *
# 1              LOAD          *
# 3              LOAD        NaN
# 4     FAD, EOAD, PD        NaN
# 5           FAD, PD          *
# 6         LOAD, FAD        NaN
# 7              LOAD        NaN
# 8   FAD, EOAD, LOAD        NaN
# 9     FAD, EOAD, PD          *
# 12    FAD, EOAD, PD        NaN
# 13             LOAD        NaN
# 14        FAD, EOAD        NaN
# 15              FAD        NaN
# 16  EOAD, LOAD, FAD        NaN
# 18    FAD, EOAD, PD          *
# 29         LOAD, PD          *
# 32          FAD, PD        NaN
# 33        FAD, LOAD          *
# 35        FAD, LOAD        NaN
# 36        FAD, LOAD        NaN
# 40    FAD, EOAD, PD        NaN
# 42  FAD, EOAD, LOAD        NaN
# 46        FAD, EOAD          *
# 47        FAD, EOAD        NaN
# 48        FAD, EOAD          *
# 50        FAD, EOAD        NaN
# 51        FAD, EOAD        NaN
# 52        FAD, EOAD        NaN
# 53        FAD, EOAD        NaN
# 54        FAD, EOAD        NaN
# 55        FAD, EOAD          *
# 56        FAD, EOAD        NaN
# 58        FAD, EOAD        NaN
# 59        FAD, EOAD          *
# 60        FAD, EOAD        NaN
# 62        FAD, EOAD        NaN
# 63        FAD, EOAD        NaN
# 64        FAD, EOAD        NaN
# 66        FAD, EOAD        NaN
# 68              FAD          *
# 69              FAD          *
# 70              FAD          *
# 71              FAD        NaN
# 72              FAD        NaN
# 73              FAD          *
# 74              FAD          *
# 77       EOAD, LOAD        NaN
# 78       EOAD, LOAD          *
# 79       EOAD, LOAD          *
# 80       EOAD, LOAD          *
# 81       EOAD, LOAD        NaN
# 85               AD          *
# 86               AD          *
# 89               AD          *
# 91               AD          *
# 92               AD          *
# 93               AD          *
# 94               AD        NaN

# %%
df_inner_ma1 = df_inner_ma1[['pmid', 'Manual Class']]

# %%
df_inner_ma2 = df_inner_ma2[['pmid', 'Manual Class']]

# %%
df_inner_ma1.to_csv('MA1_Data1.csv', sep=';', index=False)

# %%
df_inner_ma2.to_csv('MA2_Data2.csv', sep=';', index=False)

# %%
ma1txt = pd.read_csv('MA1_pmids.txt', header=None)
ma1txt.columns = ["pmid"]
df = pd.merge(df_inner_ma1, ma1txt, on='pmid', how='inner')
df = df[['pmid']]
df.to_csv('MA1_pmids1.txt', index=False, header=None)

# %%
ma2txt = pd.read_csv('MA2_pmids.txt', header=None)
ma2txt.columns = ["pmid"]
df2 = pd.merge(df_inner_ma2, ma2txt, on='pmid', how='inner')
df2 = df[['pmid']]
df2.to_csv('MA2_pmids2.txt', index=False, header=None)
